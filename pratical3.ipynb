# %%
# to split an array of 14 elements into 3 arrays, each with 2, 4, and 8
# elements in the original order
# name : Arya Lodhari
# enroll : 216270307064

import numpy as np
arr = np.array([1, 2, 3, 4, 5, 6])
newarr = np.split(arr, [2,5])
print(newarr)

# %%
# to stack arrays horizontally (column wise)
# name : Arya Lodhari
# enroll : 216270307064

import numpy as np
a = np.array([1, 2])
b = np.array([3, 4, 5])
c = np.hstack((a, b))
print(c)
